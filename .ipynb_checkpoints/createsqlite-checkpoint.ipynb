# %%
import pandas as pd

# %%
File="data/billboard_hot_100_1965_to_2018_with_lyrics_and_wordcount.csv"

# %%
file_one_df = pd.read_csv(File)

# %%
file_one_df.head(50)
# Out:
#     rankid  rank                                             artist  \
# 0     4867    67                                     Colbie Caillat
# 1     4869    69                                         David Cook
# 2     4855    55                                        Linkin Park
# 3     4857    57                                              Ne-Yo
# 4     4858    58                                Secondhand Serenade
# 5     4860    60                                         John Mayer
# 6     4861    61                                      Jordin Sparks
# 7     4864    64                                         J. Holiday
# 8     4856    56     Wyclef Jean featuring Akon, Lil Wayne and Niia
# 9     4859    59                       Flo Rida featuring will.i.am
# 10    4862    62                            Rihanna featuring Ne-Yo
# 11    4863    63               Lupe Fiasco featuring Matthew Santos
# 12    4865    65                   Kevin Rudolf featuring Lil Wayne
# ...

# %%
columns =['rankid', 'rank', 'artist', 'song', 'year', 'geniuslyrics',
       'artist_primary', 'decade', 'wordcount']

# %%
file_two_df = file_one_df.loc[file_one_df["song"] == "Psycho", columns]

# %%
file_two_df
# Out:
#       rankid  rank                               artist    song  year  \
# 5437    5806     6  Post Malone featuring Ty Dolla Sign  Psycho  2018
#
#                                            geniuslyrics artist_primary  \
# 5437  Yeah, ayy, ayy\n\n30,000 words in a rap that's...            NaN
#
#       decade  wordcount
# 5437  2010's      19964

# %%
import sqlite3 as sq

# %%
sql_data = 'data.sqlite'
conn = sq.connect(sql_data)
